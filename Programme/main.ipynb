# %% [markdown]
# <div style=" background-color: RGB(0,150,250);" >
# <h1 style="margin: auto; padding: 20px 0; color:#fff; text-align: center">PROJET 6 DATA ANALYST</h1>
# <h2 style="margin: auto; padding: 20px 0; color:#fff; text-align: center">Analyse des données de vente en ligne pour Lapage
# </h2>
# </div>

# %% [markdown]
# <div style="background-color: RGB(0,150,250);" >
# <h2 style="margin: auto; padding: 20px; color:#fff; ">Etape 1 - Importation des librairies et chargement des fichiers</h2>
# </div>

# %%
import pandas as pd
import numpy as np

# %%
customers = pd.read_csv("../Source/customers.csv", sep=";")
products = pd.read_csv("../Source/products.csv", sep=";")
transactions = pd.read_csv("../Source/Transactions.csv", sep=";")

# %% [markdown]
# <div style="background-color: RGB(0,150,250);" >
# <h2 style="margin: auto; padding: 20px; color:#fff; ">Etape 2 - Exploration fichier customers </h2>
# </div>

# %% [markdown]
# A priori - Pas de nettoyage requis

# %%
customers
# Out:
#      client_id sex  birth
# 0       c_4410   f   1967
# 1       c_7839   f   1975
# 2       c_1699   f   1984
# 3       c_5961   f   1962
# 4       c_5320   m   1943
# ...        ...  ..    ...
# 8616    c_7920   m   1956
# 8617    c_7403   f   1970
# 8618    c_5119   m   1974
# 8619    c_5643   f   1968
# 8620      c_84   f   1982
#
# [8621 rows x 3 columns]

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8621 entries, 0 to 8620
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  8621 non-null   object
#  1   sex        8621 non-null   object
#  2   birth      8621 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 202.2+ KB

# %% [markdown]
# <div style="background-color: RGB(0,150,250);" >
# <h2 style="margin: auto; padding: 20px; color:#fff; ">Etape 3 - Exploration fichier products </h2>
# </div>

# %%
products
# Out:
#      id_prod   price  categ
# 0     0_1421   19.99      0
# 1     0_1368    5.13      0
# 2      0_731   17.99      0
# 3      1_587    4.99      1
# 4     0_1507    3.99      0
# ...      ...     ...    ...
# 3281    2_23  115.99      2
# 3282   0_146   17.14      0
# 3283   0_802   11.22      0
# 3284   1_140   38.56      1
# 3285  0_1920   25.16      0
#
# [3286 rows x 3 columns]

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3286 entries, 0 to 3285
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id_prod  3286 non-null   object
#  1   price    3286 non-null   float64
#  2   categ    3286 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 77.1+ KB

# %% [markdown]
# <div style="background-color: RGB(0,150,250);" >
# <h2 style="margin: auto; padding: 20px; color:#fff; ">Etape 4 - Exploration fichier transactions </h2>
# </div>

# %%
transactions
# Out:
#        id_prod                        date session_id client_id
# 0       0_1259  2021-03-01 00:01:07.843138        s_1     c_329
# 1       0_1390  2021-03-01 00:02:26.047414        s_2     c_664
# 2       0_1352  2021-03-01 00:02:38.311413        s_3     c_580
# 3       0_1458  2021-03-01 00:04:54.559692        s_4    c_7912
# 4       0_1358  2021-03-01 00:05:18.801198        s_5    c_2033
# ...        ...                         ...        ...       ...
# 687529   1_508  2023-02-28 23:49:03.148402   s_348444    c_3573
# 687530    2_37  2023-02-28 23:51:29.318531   s_348445      c_50
# 687531   1_695  2023-02-28 23:53:18.929676   s_348446     c_488
# 687532  0_1547  2023-02-28 23:58:00.107815   s_348447    c_4848
# 687533  0_1398  2023-02-28 23:58:30.792755   s_348435    c_3575
#
# [687534 rows x 4 columns]

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 687534 entries, 0 to 687533
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id_prod     687534 non-null  object
#  1   date        687534 non-null  object
#  2   session_id  687534 non-null  object
#  3   client_id   687534 non-null  object
# dtypes: object(4)
# memory usage: 21.0+ MB

# %% [markdown]
# <div style="background-color: RGB(0,150,250);" >
# <h2 style="margin: auto; padding: 20px; color:#fff; ">Etape 5 - Fusion des tables </h2>
# </div>

# %%
transaction_product = pd.merge(transactions, products, how='left', on='id_prod')
table_final = pd.merge(transaction_product, customers, how='left', on='client_id')
table_final
# Out:
#        id_prod                        date session_id client_id  price  categ  \
# 0       0_1259  2021-03-01 00:01:07.843138        s_1     c_329  11.99      0
# 1       0_1390  2021-03-01 00:02:26.047414        s_2     c_664  19.37      0
# 2       0_1352  2021-03-01 00:02:38.311413        s_3     c_580   4.50      0
# 3       0_1458  2021-03-01 00:04:54.559692        s_4    c_7912   6.55      0
# 4       0_1358  2021-03-01 00:05:18.801198        s_5    c_2033  16.49      0
# ...        ...                         ...        ...       ...    ...    ...
# 687529   1_508  2023-02-28 23:49:03.148402   s_348444    c_3573  21.92      1
# 687530    2_37  2023-02-28 23:51:29.318531   s_348445      c_50  48.99      2
# 687531   1_695  2023-02-28 23:53:18.929676   s_348446     c_488  26.99      1
# 687532  0_1547  2023-02-28 23:58:00.107815   s_348447    c_4848   8.99      0
# 687533  0_1398  2023-02-28 23:58:30.792755   s_348435    c_3575   4.52      0
#
#        sex  birth
# 0        f   1967
# 1        m   1960
# 2        m   1988
# 3        f   1989
# 4        f   1956
# ...     ..    ...
# 687529   f   1996
# 687530   f   1994
# 687531   f   1985
# 687532   m   1953
# 687533   f   1981
#
# [687534 rows x 8 columns]
