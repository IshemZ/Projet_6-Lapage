# %% [markdown]
# <div style=" background-color: RGB(0,150,250);" >
# <h1 style="margin: auto; padding: 20px 0; color:#fff; text-align: center">PROJET 6 DATA ANALYST</h1>
# <h2 style="margin: auto; padding: 20px 0; color:#fff; text-align: center">Analyse des données de vente en ligne pour Lapage
# </h2>
# </div>

# %% [markdown]
# <div style="background-color: RGB(0,150,250);" >
# <h2 style="margin: auto; padding: 20px; color:#fff; ">Etape 1 - Importation des librairies et chargement des fichiers</h2>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import biblio_modules
import pyarrow

# %%
customers = pd.read_csv("../Source/customers.csv", sep=";")
products = pd.read_csv("../Source/products.csv", sep=";")
transactions = pd.read_csv("../Source/Transactions.csv", sep=";")

# %% [markdown]
# <div style="background-color: RGB(0,150,250);" >
# <h2 style="margin: auto; padding: 20px; color:#fff; ">Etape 2 - Exploration fichier customers </h2>
# </div>

# %%
customers.head()
# Out:
#   client_id sex  birth
# 0    c_4410   f   1967
# 1    c_7839   f   1975
# 2    c_1699   f   1984
# 3    c_5961   f   1962
# 4    c_5320   m   1943

# %%
products.head()
# Out:
#   id_prod  price  categ
# 0  0_1421  19.99      0
# 1  0_1368   5.13      0
# 2   0_731  17.99      0
# 3   1_587   4.99      1
# 4  0_1507   3.99      0

# %%
transactions.head()
# Out:
#   id_prod                        date session_id client_id
# 0  0_1259  2021-03-01 00:01:07.843138        s_1     c_329
# 1  0_1390  2021-03-01 00:02:26.047414        s_2     c_664
# 2  0_1352  2021-03-01 00:02:38.311413        s_3     c_580
# 3  0_1458  2021-03-01 00:04:54.559692        s_4    c_7912
# 4  0_1358  2021-03-01 00:05:18.801198        s_5    c_2033

# %% [markdown]
# <div style="background-color: RGB(0,150,250);" >
# <h2 style="margin: auto; padding: 20px; color:#fff; ">Etape 5 - Fusion de product et transaction (OUTER JOIN) </h2>
# </div>

# %%
df_transaction_product = pd.merge(transactions, customers, how='outer', on='client_id', indicator=True, )
df_transaction_product
# Out:
#        id_prod                        date session_id client_id sex  birth  \
# 0       0_1470  2021-06-11 21:02:39.382765    s_47346       c_1   m   1955
# 1        0_513  2021-07-21 22:41:38.769525    s_65433       c_1   m   1955
# 2       0_1186  2021-07-25 12:17:34.446678    s_66947       c_1   m   1955
# 3       0_1448  2021-07-26 17:37:29.438136    s_67467       c_1   m   1955
# 4       0_1475  2021-07-27 10:30:00.293075    s_67769       c_1   m   1955
# ...        ...                         ...        ...       ...  ..    ...
# 687550  0_1360  2023-01-15 17:53:15.077669   s_327362     c_999   m   1964
# 687551   1_351  2023-01-21 17:16:06.807620   s_330231     c_999   m   1964
# 687552   1_727  2023-01-21 17:40:50.856434   s_330231     c_999   m   1964
# 687553  0_1442  2023-01-28 13:12:42.429052   s_333631     c_999   m   1964
# 687554   1_676  2023-02-10 23:59:59.414026   s_339757     c_999   m   1964
#
#        _merge
# 0        both
# 1        both
# 2        both
# 3        both
# 4        both
# ...       ...
# 687550   both
# 687551   both
# 687552   both
# 687553   both
# 687554   both
#
# [687555 rows x 7 columns]

# %%
df_transaction_product.isna().sum()
# Out:
# id_prod       21
# date          21
# session_id    21
# client_id      0
# sex            0
# birth          0
# _merge         0
# dtype: int64

# %%
df_transaction_product.loc[df_transaction_product['session_id'].isna()]
# Out:
#        id_prod date session_id client_id   price  categ
# 6073    0_1014  NaN        NaN       NaN    1.15      0
# 6511    0_1016  NaN        NaN       NaN   35.06      0
# 8723    0_1025  NaN        NaN       NaN   24.99      0
# 21687   0_1062  NaN        NaN       NaN   20.08      0
# 40971   0_1119  NaN        NaN       NaN    2.99      0
# 94245   0_1318  NaN        NaN       NaN   20.92      0
# 297077  0_1620  NaN        NaN       NaN    0.80      0
# 299185  0_1624  NaN        NaN       NaN   24.50      0
# 311123  0_1645  NaN        NaN       NaN    2.99      0
# 323013  0_1780  NaN        NaN       NaN    1.67      0
# 325137  0_1800  NaN        NaN       NaN   22.05      0
# 387651  0_2308  NaN        NaN       NaN   20.28      0
# 389726   0_299  NaN        NaN       NaN   22.99      0
# 390221   0_310  NaN        NaN       NaN    1.94      0
# 390689   0_322  NaN        NaN       NaN    2.99      0
# 397070   0_510  NaN        NaN       NaN   23.66      0
# 415475     1_0  NaN        NaN       NaN   31.82      1
# 514820   1_394  NaN        NaN       NaN   39.73      1
# 685998    2_72  NaN        NaN       NaN  141.32      2
# 686501    2_86  NaN        NaN       NaN  132.36      2
# 686502    2_87  NaN        NaN       NaN  220.99      2

# %%
#df_transaction_product.to_csv("../Source/Data_processed/Table_merged.csv", index=False, sep=";")

# %% [markdown]
# <div style="background-color: RGB(900,80,50);" >
# <h3 style="margin: auto; padding: 10px; color:#fff; "> Partie 1 - Analyse des indicateurs de vente </h2>
# </div>
